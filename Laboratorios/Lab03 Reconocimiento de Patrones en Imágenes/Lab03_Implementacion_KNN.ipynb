# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/Detroxsys/RP-2023-2/blob/main/Laboratorios/Lab03%20Reconocimiento%20de%20Patrones%20en%20Im%C3%A1genes/Lab03_Implementacion_KNN.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 03: Implementar KNN

# %%
#Librerías a utilizar
import numpy as np #Para distancias y manipulacion de arreglos
import matplotlib.pyplot as plt #Graficación.

# %% [markdown]
# ## Implementar el algoritmo de KNN (6 puntos)

# %%
def euclidean_distance(x1, x2):
    """
      Distancia euclidiana
    """
    x1=np.array(x1) #Convertimos a numpy de ser necesario
    x2=np.array(x2) #Convertimos a numpy de ser necesario
    return np.linalg.norm(x1-x2,2) #Retornamos la distancia euclideana.

# %%
class KNN(): 
  """
    KVecinos:
      Clase que implementa el algoritmo de los K-vecinos para agrupar
      conjuntos de datos. 

    Atributos
    -----------------
    k: número de vecinos a considerar. 
    metric: Métrica a utilizar para las distancias. 

  """
  def __init__(self, k, metric):
    """
      Constructor de la clase. 
    """
    self.k = k
    self.metric =metric

  def fit(self, X, y): 
    """
      Recibe los datos de entrenamiento
      X: numpy.ndaaray con los patrones de cada clase. 
      y: numpy.array con las etiquetas para cada clase. 
    """
    self.X = X
    self.y = y

  def predict(self,x): 
    """
      Clasifica el patron respecto al conjunto de entrenamiento

    """
    return clase

# %% [markdown]
# ## Caso de prueba (1.5 puntos)

# %%
#Patrones del ejercicio. 
X=[[0,3],[0,2],[0,1],[0,0],[-1,0],[-2,0],
           [1,3],[1,1],[1,0],[0,-1]]
X= np.array(X)
y = [1]*6 + [2]*4
y = np.array(y)
print(X)
#Patrón a clasificar
newX = np.array([1,4]).reshape(1,-1)

#Clasificador (cambiar por el que implementen)
from sklearn.neighbors import KNeighborsClassifier
knn1 = KNeighborsClassifier(n_neighbors=1)
knn1.fit(X,y)
knn3 = KNeighborsClassifier(n_neighbors=3)
knn3.fit(X,y)
knn5 = KNeighborsClassifier(n_neighbors=5)
knn5.fit(X, y) 

#Imprimimos los resultados
print('Según el algoritmo de K-Vecinos')
print('El patrón (1,4)')
print(f'Usando 1 vecino pertece a la clase: {knn1.predict(newX)}')
print(f'Usando 3 vecino pertece a la clase: {knn3.predict(newX)}')
print(f'Usando 5 vecino pertece a la clase: {knn5.predict(newX)}')
# Out:
# [[ 0  3]
#  [ 0  2]
#  [ 0  1]
#  [ 0  0]
#  [-1  0]
#  [-2  0]
#  [ 1  3]
#  [ 1  1]
#  [ 1  0]
#  [ 0 -1]]
# Según el algoritmo de K-Vecinos
# El patrón (1,4)
# Usando 1 vecino pertece a: [2]
# Usando 3 vecino pertece a: [1]
# Usando 5 vecino pertece a: [1]

# %% [markdown]
# ## Gráfica (1.5 puntos)

# %% [markdown]
# ## Pruebe con otra métrica (1 puntos)
#
# Utilizando 1,3,5 vecinos y también grafique.
